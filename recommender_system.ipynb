# %% [markdown]
# ## Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = 'drive/My Drive/Colab Notebooks/RecSys/'

# %% [markdown]
# ## Libraries

# %%
# !pip install rake_nltk
# !pip install nagisa

import pandas as pd
import numpy as np
import nagisa
import nltk

from rake_nltk import Rake
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rake_nltk in /usr/local/lib/python3.7/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.7/dist-packages (from rake_nltk) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.64.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nagisa in /usr/local/lib/python3.7/dist-packages (0.2.7)
# Requirement already satisfied: DyNet in /usr/local/lib/python3.7/dist-packages (from nagisa) (2.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nagisa) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nagisa) (1.21.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from DyNet->nagisa) (0.29.32)

# %% [markdown]
# nagisa library is used for splitting Japanese text in order to achieve this project goal.

# %% [markdown]
# ## Load the Dataset

# %% [markdown]
# Load the IMDB movie dataset obtained from [data.world](https://data.world/studentoflife/imdb-top-250-lists-and-5000-or-so-data-records) website.

# %%
df = pd.read_csv(path + '/data/IMDB_Top250movies2_OMDB_Detailed.csv')
df.head()
# Out:
#    Unnamed: 0                     Title        Title-JA  Year     Rated  \
# 0           1  The Shawshank Redemption      ショーシャンクの空に  1994         R
# 1           2             The Godfather        ゴッドファーザー  1972         R
# 2           3    The Godfather: Part II  ゴッドファーザー：パートII  1974         R
# 3           4           The Dark Knight          ダークナイト  2008     PG-13
# 4           5              12 Angry Men     12人の怒っている男性  1957  APPROVED
#
#       Released  Runtime                 Genre      Genre-JA  \
# 0  14 Oct 1994  142 min          Crime, Drama         犯罪ドラマ
# 1  24 Mar 1972  175 min          Crime, Drama         犯罪ドラマ
# 2  20 Dec 1974  202 min          Crime, Drama         犯罪ドラマ
# 3  18 Jul 2008  152 min  Action, Crime, Drama  アクション、犯罪、ドラマ
# 4  01 Apr 1957   96 min          Crime, Drama         犯罪ドラマ
#
#                Director  ... tomatoConsensus tomatoUserMeter tomatoUserRating  \
# 0        Frank Darabont  ...             NaN             NaN              NaN
# 1  Francis Ford Coppola  ...             NaN             NaN              NaN
# 2  Francis Ford Coppola  ...             NaN             NaN              NaN
# 3     Christopher Nolan  ...             NaN             NaN              NaN
# 4          Sidney Lumet  ...             NaN             NaN              NaN
#
#   tomatoUserReviews                                          tomatoURL  \
# 0               NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1               NaN         http://www.rottentomatoes.com/m/godfather/
# 2               NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3               NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4               NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website Response
# 0                                                NaN     True
# 1                        http://www.thegodfather.com     True
# 2                       http://www.thegodfather.com/     True
# 3               http://thedarkknight.warnerbros.com/     True
# 4  http://www.criterion.com/films/27871-12-angry-men     True
#
# [5 rows x 44 columns]

# %%
# Keep only necessary columns (Title, Genre, Director, Actors, Plot)
df_for_pre = df[['Title', 'Title-JA', 'Genre', 'Genre-JA', 'Director', 'Director-JA', 'Actors', 'Actors-JA', 'Plot', 'Plot-JA']]
df_for_pre.head()
# Out:
#                       Title        Title-JA                 Genre  \
# 0  The Shawshank Redemption      ショーシャンクの空に          Crime, Drama
# 1             The Godfather        ゴッドファーザー          Crime, Drama
# 2    The Godfather: Part II  ゴッドファーザー：パートII          Crime, Drama
# 3           The Dark Knight          ダークナイト  Action, Crime, Drama
# 4              12 Angry Men     12人の怒っている男性          Crime, Drama
#
#        Genre-JA              Director      Director-JA  \
# 0         犯罪ドラマ        Frank Darabont       フランク・ダラボント
# 1         犯罪ドラマ  Francis Ford Coppola  フランシス・フォード・コッポラ
# 2         犯罪ドラマ  Francis Ford Coppola  フランシス・フォード・コッポラ
# 3  アクション、犯罪、ドラマ     Christopher Nolan     クリストファー・ノーラン
# 4         犯罪ドラマ          Sidney Lumet         シドニールメット
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                     Actors-JA  \
# 0      ティム・ロビンズ、モーガン・フリーマン、ボブ・ガントン、ウィリアム・サドラー
# 1  マーロン・ブランド、アル・パチーノ、ジェームズ・カーン、リチャード・S・カステラーノ
# 2      アル・パチーノ、ロバート・デュバル、ダイアン・キートン、ロバート・デ・ニーロ
# 3    クリスチャン・ベール、ヒース・レジャー、アーロン・エックハート、マイケル・ケイン
# 4      マーティン・バルサム、ジョン・フィードラー、リー・J・コブ、例えばマーシャル
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                              Plot-JA
# 0  2人の投獄された男性が何年にもわたって絆を結び、共通の良識の行為を通じて慰めと最終的なred...
# 1        組織化された犯罪王朝の老化した家長は、彼の秘密帝国の消極的な息子に支配権を譲渡します。
# 2  1920年代のニューヨークのヴィトコルレオーネの初期の人生とキャリアは、息子のマイケルが家族...
# 3  ジョーカーとして知られる脅威が彼の神秘的な過去から現れたとき、彼はゴッサムの人々に大混乱と混...
# 4      ju審員は、同僚に証拠を再考することを強制することにより、正義の流産を防止しようとします。

# %%
# Check entry types, and missing values
df_for_pre.info()
print('\nMissing values:  ', df_for_pre.isnull().sum().values.sum())
df_for_pre.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        250 non-null    object
#  1   Title-JA     250 non-null    object
#  2   Genre        250 non-null    object
#  3   Genre-JA     250 non-null    object
#  4   Director     250 non-null    object
#  5   Director-JA  250 non-null    object
#  6   Actors       250 non-null    object
#  7   Actors-JA    250 non-null    object
#  8   Plot         250 non-null    object
#  9   Plot-JA      250 non-null    object
# dtypes: object(10)
# memory usage: 19.7+ KB
#
# Missing values:   0
# Title          0
# Title-JA       0
# Genre          0
# Genre-JA       0
# Director       0
# Director-JA    0
# Actors         0
# Actors-JA      0
# Plot           0
# Plot-JA        0
# dtype: int64

# %% [markdown]
# ## Data Pre-processing

# %%
jpn_stop_words = ["あそこ","あっ","あの","あのかた","あの人","あり","あります","ある","あれ","い","いう","います","いる","う","うち","え","お","および","おり","おります","か","かつて","から","が","き","ここ","こちら","こと","この","これ","これら","さ","さらに","し","しかし","する","ず","せ","せる","そこ","そして","その","その他","その後","それ","それぞれ","それで","た","ただし","たち","ため","たり","だ","だっ","だれ","つ","て","で","でき","できる","です","では","でも","と","という","といった","とき","ところ","として","とともに","とも","と共に","どこ","どの","な","ない","なお","なかっ","ながら","なく","なっ","など","なに","なら","なり","なる","なん","に","において","における","について","にて","によって","により","による","に対して","に対する","に関する","の","ので","のみ","は","ば","へ","ほか","ほとんど","ほど","ます","また","または","まで","も","もの","ものの","や","よう","より","ら","られ","られる","れ","れる","を","ん","何","及び","彼","彼女","我々","特に","私","私達","貴方","貴方方"]

# %%
# Rake_JA
import string
import unicodedata

# !pip install mecab-python3
import MeCab


class Rake_JA:
    def __init__(self):
        self.tagger = MeCab.Tagger("-Owakati")
    
    def remove_punctuation(self,text):
        text = unicodedata.normalize("NFKC", text)  # 全角記号をざっくり半角へ置換（でも不完全）
        # 記号を消し去るための魔法のテーブル作成
        table = str.maketrans("", "", string.punctuation  + "「」、。・※" + string.digits)
        text = text.translate(table)

        return text
        
    def get_word_score(self, word_list):
        freq = {}
        deg = {}

        for word in word_list:
            freq[word] = (freq.get(word) or 0) + 1
            deg[word] = (deg.get(word) or 0) + len(word) - 1 # word length must be > 1 to be considered as a Japanese 'word'
      
        scores = {}
        for word in word_list:
            scores[word] = deg[word]/freq[word]
        
        scores = {k:v for k, v in  sorted(scores.items(), key=lambda item: item[1], reverse=True)}
      
        return scores
    
    def get_keywords(self, text, limit=0):
        parsed_text = self.tagger.parse(text)
        raw_word_list = self.remove_punctuation(parsed_text).split()
        word_list = [word for word in raw_word_list if word not in jpn_stop_words ]
        
        score_list = self.get_word_score(word_list)
        
        if limit == 0:
            return list(score_list.keys())
        else:
            return list(score_list.keys())[:limit]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.7/dist-packages (1.0.5)

# %%
# Remove punctuations from Plot
df_for_pre['Plot'] = df_for_pre['Plot'].str.replace('[^\w\s]','')
df_for_pre.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Title        Title-JA                 Genre  \
# 0  The Shawshank Redemption      ショーシャンクの空に          Crime, Drama
# 1             The Godfather        ゴッドファーザー          Crime, Drama
# 2    The Godfather: Part II  ゴッドファーザー：パートII          Crime, Drama
# 3           The Dark Knight          ダークナイト  Action, Crime, Drama
# 4              12 Angry Men     12人の怒っている男性          Crime, Drama
#
#        Genre-JA              Director      Director-JA  \
# 0         犯罪ドラマ        Frank Darabont       フランク・ダラボント
# 1         犯罪ドラマ  Francis Ford Coppola  フランシス・フォード・コッポラ
# 2         犯罪ドラマ  Francis Ford Coppola  フランシス・フォード・コッポラ
# 3  アクション、犯罪、ドラマ     Christopher Nolan     クリストファー・ノーラン
# 4         犯罪ドラマ          Sidney Lumet         シドニールメット
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                     Actors-JA  \
# 0      ティム・ロビンズ、モーガン・フリーマン、ボブ・ガントン、ウィリアム・サドラー
# 1  マーロン・ブランド、アル・パチーノ、ジェームズ・カーン、リチャード・S・カステラーノ
# 2      アル・パチーノ、ロバート・デュバル、ダイアン・キートン、ロバート・デ・ニーロ
# 3    クリスチャン・ベール、ヒース・レジャー、アーロン・エックハート、マイケル・ケイン
# 4      マーティン・バルサム、ジョン・フィードラー、リー・J・コブ、例えばマーシャル
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                              Plot-JA Key_words
# 0  2人の投獄された男性が何年にもわたって絆を結び共通の良識の行為を通じて慰めと最終的なredい...
# 1          組織化された犯罪王朝の老化した家長は彼の秘密帝国の消極的な息子に支配権を譲渡します
# 2  1920年代のニューヨークのヴィトコルレオーネの初期の人生とキャリアは息子のマイケルが家族の...
# 3  ジョーカーとして知られる脅威が彼の神秘的な過去から現れたとき彼はゴッサムの人々に大混乱と混乱...
# 4         ju審員は同僚に証拠を再考することを強制することにより正義の流産を防止しようとします

# %%
# Extract key words from Plot to a list
df_for_pre['Key_words'] = ''   # initializing a new column
r = Rake()   # use Rake to discard stop words (based on english stopwords from NLTK)

for index, row in df_for_pre.iterrows():
    r.extract_keywords_from_text(row['Plot'])   # to extract key words from Plot, default in lower case
    key_words_dict_scores = r.get_word_degrees()    # to get dictionary with key words and their scores
    row['Key_words'] = list(key_words_dict_scores.keys())   # to assign list of key words to new column

df_for_pre
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.7/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-26-cfbaa693dffc> in <module>()
#       1 # Extract key words from Plot to a list
#       2 df_for_pre['Key_words'] = ''   # initializing a new column
# ----> 3 r = Rake()   # use Rake to discard stop words (based on english stopwords from NLTK)
#       4
#       5 for index, row in df_for_pre.iterrows():
#
# /usr/local/lib/python3.7/dist-packages/rake_nltk/rake.py in __init__(self, stopwords, punctuations, language, ranking_metric, max_length, min_length, include_repeated_phrases, sentence_tokenizer, word_tokenizer)
#      82             self.stopwords = stopwords
#      83         else:
# ---> 84             self.stopwords = set(nltk.corpus.stopwords.words(language))
#      85
#      86         # If punctuations are not provided we ignore all punctuation symbols.
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /usr/local/lib/python3.7/dist-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
